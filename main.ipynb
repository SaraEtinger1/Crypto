# %% [markdown]
# !pip install xlrd
# !pip install pandas
# !pip install openpyxl
# !pip install matplotlib
# !pip install pyplot

# %%
import pandas as pd
import xlrd
from matplotlib import pyplot as plt
import numpy as np
import openpyxl

data=pd.read_excel('E9367CD7-C9BA-4C8B-86C9-53837D81AD49.Bitcoin Historical Data (1).xlsx')
data.head()

price=data['Price']
minPrice=price.min()
maxPrice=price.max()
step = 5000
xpoints = np.arange(minPrice, maxPrice+step,step) #כל הספרות בדילוגים של 500
# חישוב תדירות לכל טווח מחיר
hist, bins = np.histogram(price, bins=xpoints)
plt.plot(xpoints[:-1], hist,label="Price")
plt.title("distribution")
plt.xlabel("sum")
plt.ylabel("cnt")
plt.show()

Crypto_Volatility_Index=data['Crypto Volatility Index']
minCrypto_Volatility_Index=Crypto_Volatility_Index.min()
maxCrypto_Volatility_Index=Crypto_Volatility_Index.max()
step = 1
xpoints = np.arange(minCrypto_Volatility_Index, maxCrypto_Volatility_Index+step,step) #כל הספרות בדילוגים של 1
hist, bins = np.histogram(Crypto_Volatility_Index, bins=xpoints)
plt.plot(xpoints[:-1], hist,label="Crypto_Volatility_Index")
plt.title("distribution")
plt.xlabel("sum")
plt.ylabel("cnt")
plt.legend()
plt.show()

change=data['Change %']
minChange=change.min()
maxChange=change.max()
step = 0.01
xpoints = np.arange(minChange, maxChange+step,step) #כל הספרות בדילוגים של 1%
hist, bins = np.histogram(change, bins=xpoints)
plt.plot(xpoints[:-1], hist,label="Change")
plt.title("distribution")
plt.xlabel("sum")
plt.ylabel("cnt")
plt.legend()
plt.show()

SN_P=data['SN&P Adjusted']
minSN_P=SN_P.min()
maxSN_P=SN_P.max()
step = 100
xpoints = np.arange(minSN_P, maxSN_P+step,step) #כל הספרות בדילוגים של 1
hist, bins = np.histogram(SN_P, bins=xpoints)
plt.plot(xpoints[:-1], hist,label="SN_P")
plt.title("distribution")
plt.xlabel("sum")
plt.ylabel("cnt")
plt.legend()
plt.show()

DXY=data['DXY Adjusted']
minDXY=DXY.min()
maxDXY=DXY.max()
step = 1
xpoints = np.arange(minDXY, maxDXY+step,step) #כל הספרות בדילוגים של 1
hist, bins = np.histogram(DXY, bins=xpoints)
plt.plot(xpoints[:-1], hist,label="DXY")
plt.title("distribution")
plt.xlabel("sum")
plt.ylabel("cnt")
plt.legend()
plt.show()

GOLD=data['GOLD Adjusted']
minGOLD=GOLD.min()
maxGOLD=GOLD.max()
step = 10
xpoints = np.arange(minGOLD, maxGOLD+step,step) #כל הספרות בדילוגים של 1
hist, bins = np.histogram(GOLD, bins=xpoints)
plt.plot(xpoints[:-1], hist,label="GOLD")
plt.title("distribution")
plt.xlabel("sum")
plt.ylabel("cnt")
plt.legend()
plt.show()

ETH=data['ETH Price']
minETH=ETH.min()
maxETH=ETH.max()
step = 100
xpoints = np.arange(minETH, maxETH+step,step) #כל הספרות בדילוגים של 1
hist, bins = np.histogram(ETH, bins=xpoints)
plt.plot(xpoints[:-1], hist,label="ETH")
plt.title("distribution")
plt.xlabel("sum")
plt.ylabel("cnt")
plt.legend()
plt.show()

# לא עובד, בגלל שיש K
# ETH_V=data['ETH Vol.']
# minETH_V=ETH_V.min()
# maxETH_V=ETH_V.max()
# step = 500
# xpoints = np.arange(minETH_V, maxETH_V + step,step) #כל הספרות בדילוגים של 1
# hist, bins = np.histogram(ETH_V, bins=xpoints)
# plt.plot(xpoints[:-1], hist,label="ETH_V")
# plt.title("distribution")
# plt.xlabel("sum")
# plt.ylabel("cnt")
# plt.legend()
# plt.show()

OIL=data['OIL Price Adjusted']
minOIL=OIL.min()
maxOIL=OIL.max()
step = 1
xpoints = np.arange(minOIL, maxOIL+step,step) #כל הספרות בדילוגים של 1
hist, bins = np.histogram(ETH, bins=xpoints)
plt.plot(xpoints[:-1], hist,label="OIL")
plt.title("distribution")
plt.xlabel("sum")
plt.ylabel("cnt")
plt.legend()
plt.show()

BTC=data['BTC_Hashprice']
minBTC=BTC.min()
maxBTC=BTC.max()
step = 0.000001
xpoints = np.arange(minBTC, maxBTC+step,step) #כל הספרות בדילוגים של 1
hist, bins = np.histogram(BTC, bins=xpoints)
plt.plot(xpoints[:-1], hist,label="BTC")
plt.title("distribution")
plt.xlabel("sum")
plt.ylabel("cnt")
plt.legend()
plt.show()

Crypto=data['Crypto Volatility Index']
minCrypto=Crypto.min()
maxCrypto=Crypto.max()
step = 10
xpoints = np.arange(minCrypto, maxCrypto+step,step) #כל הספרות בדילוגים של 1
hist, bins = np.histogram(Crypto, bins=xpoints)
plt.plot(xpoints[:-1], hist,label="Crypto")
plt.title("distribution")
plt.xlabel("sum")
plt.ylabel("cnt")
plt.legend()
plt.show()

# %%
import pandas as pd
import xlrd
from matplotlib import pyplot as plt
import numpy as np
import openpyxl

df = pd.read_excel(r'E9367CD7-C9BA-4C8B-86C9-53837D81AD49.Bitcoin Historical Data (1).xlsx')

# יצירת עמודת טווחים זהב
# min_val = int(df['GOLD Adjusted'].min())
min_val = int(1174)
max_val = int(1473)
ranges = list(range(min_val, max_val + 301, 301))
df['ranges_GOLD_Adjusted'] = pd.cut(df['GOLD Adjusted'], bins=ranges, labels=[f"{r}-{r+299}" for r in ranges[:-1]])
# print(df.ranges_GOLD_Adjusted)

import copy
df1 = copy.deepcopy(df)

min_val = int(1474)
max_val = int(2073)
ranges = list(range(min_val, max_val + 599, 599))
df1['ranges_GOLD_Adjusted'] = pd.cut(df1['GOLD Adjusted'], bins=ranges, labels=[f"{r}-{r+598}" for r in ranges[:-1]])
# print(df1.ranges_GOLD_Adjusted)

# טבלה חדשה לזהב המחשבת אחוזים
# טען את נתוני 'df'
# dfGold = df.copy.deepcopy()
import copy
dfGold = copy.deepcopy(df)

# ודא ש-GOLD Adjusted הוא מסוג int
dfGold['GOLD Adjusted'] = dfGold['GOLD Adjusted'].astype(int)
# צור טבלה חדשה עם טווחים, ספירה, סכום TARGET_VALUE וחישוב אחוז
grouped_data = (
    dfGold.pivot_table(
        index='ranges_GOLD_Adjusted',
        values=['GOLD Adjusted', 'Target Value'],
        aggfunc={'GOLD Adjusted': 'count', 'Target Value': ['sum', 'mean']},
    ).reset_index()
)
print(grouped_data)

import copy
dfGold1 = copy.deepcopy(df1)

# ודא ש-GOLD Adjusted הוא מסוג int
dfGold1['GOLD Adjusted'] = dfGold1['GOLD Adjusted'].astype(int)
# צור טבלה חדשה עם טווחים, ספירה, סכום TARGET_VALUE וחישוב אחוז
grouped_data = (
    dfGold1.pivot_table(
        index='ranges_GOLD_Adjusted',
        values=['GOLD Adjusted', 'Target Value'],
        aggfunc={'GOLD Adjusted': 'count', 'Target Value': ['sum', 'mean']},
    ).reset_index()
)
print(grouped_data)
# Out:
#   ranges_GOLD_Adjusted GOLD Adjusted Target Value
#                                count         mean  sum
# 0            1174-1473           964     0.369295  356
#   ranges_GOLD_Adjusted GOLD Adjusted Target Value
#                                count         mean  sum
# 0            1474-2072          1634     0.258262  422
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\1802291132.py:36: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dfGold.pivot_table(
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\1802291132.py:51: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dfGold1.pivot_table(

# %%
# יצירת עמודת טווחים SN&P Adjusted
# min_val = int(df['GOLD Adjusted'].min())
min_val = int(2191)
max_val = int(2690)
ranges = list(range(min_val, max_val + 501, 501))
df['ranges_SN&P Adjusted'] = pd.cut(df['SN&P Adjusted'], bins=ranges, labels=[f"{r}-{r+499}" for r in ranges[:-1]])
# print(df.ranges_GOLD_Adjusted)

import copy
df1 = copy.deepcopy(df)

min_val = int(2691)
max_val = int(5690)
ranges = list(range(min_val, max_val + 2999, 2999))
df1['ranges_SN&P Adjusted'] = pd.cut(df1['SN&P Adjusted'], bins=ranges, labels=[f"{r}-{r+2998}" for r in ranges[:-1]])
# print(df1.ranges_GOLD_Adjusted)

# טבלה חדשה לזהב המחשבת אחוזים
# טען את נתוני 'df'
# dfGold = df.copy.deepcopy()
import copy
dfGold = copy.deepcopy(df)


# ודא ש-SN&P Adjusted הוא מסוג int
dfGold['SN&P Adjusted'] = dfGold['SN&P Adjusted'].astype(int)
# צור טבלה חדשה עם טווחים, ספירה, סכום TARGET_VALUE וחישוב אחוז
grouped_data = (
    dfGold.pivot_table(
        index='ranges_SN&P Adjusted',
        values=['SN&P Adjusted', 'Target Value'],
        aggfunc={'SN&P Adjusted': 'count', 'Target Value': ['sum', 'mean']},
    ).reset_index()
)
print(grouped_data)

import copy
dfGold1 = copy.deepcopy(df1)

# ודא ש-SN&P Adjusted הוא מסוג int
dfGold1['SN&P Adjusted'] = dfGold1['SN&P Adjusted'].astype(int)
# צור טבלה חדשה עם טווחים, ספירה, סכום TARGET_VALUE וחישוב אחוז
grouped_data = (
    dfGold1.pivot_table(
        index='ranges_SN&P Adjusted',
        values=['SN&P Adjusted', 'Target Value'],
        aggfunc={'SN&P Adjusted': 'count', 'Target Value': ['sum', 'mean']},
    ).reset_index()
)
print(grouped_data)
# Out:
#   ranges_SN&P Adjusted SN&P Adjusted Target Value
#                                count         mean  sum
# 0            2191-2690           521     0.441459  230
#   ranges_SN&P Adjusted SN&P Adjusted Target Value
#                                count         mean  sum
# 0            2691-5689          2129     0.267262  569
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\1208775643.py:29: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dfGold.pivot_table(
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\1208775643.py:44: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dfGold1.pivot_table(

# %%
# יצירת טבלת טווחים SN&P Adjusted
min_val = int(df['SN&P Adjusted'].min())
max_val = int(df['SN&P Adjusted'].max())
ranges = list(range(min_val, max_val + 500, 500))
df['ranges_SN&P_Adjusted'] = pd.cut(df['SN&P Adjusted'], bins=ranges, labels=[f"{r}-{r+499}" for r in ranges[:-1]])

print(df['ranges_SN&P_Adjusted'])

df_SNP_Adjusted = df.copy()

# חישוב סטטיסטיקות עבור כל טווח
grouped_data = df_SNP_Adjusted.pivot_table(
    index='ranges_SN&P_Adjusted',
    values=['SN&P Adjusted', 'Target Value'],
    aggfunc={'SN&P Adjusted': 'count', 'Target Value': ['sum', 'mean']},
)

# הצגת הטבלה
print(grouped_data)
# Out:
# 0       4691-5190
# 1       4691-5190
# 2       4691-5190
# 3       4691-5190
# 4       4691-5190
#           ...
# 2643    2191-2690
# 2644    2191-2690
# 2645    2191-2690
# 2646    2191-2690
# 2647    2191-2690
# Name: ranges_SN&P_Adjusted, Length: 2648, dtype: category
# Categories (7, object): ['2191-2690' < '2691-3190' < '3191-3690' < '3691-4190' < '4191-4690' < '4691-5190' < '5191-5690']
#                      SN&P Adjusted Target Value
#                              count         mean  sum
# ranges_SN&P_Adjusted
# 2191-2690                      519     0.441233  229
# 2691-3190                      681     0.280470  191
# 3191-3690                      270     0.214815   58
# 3691-4190                      521     0.295585  154
# 4191-4690                      512     0.244141  125
# 4691-5190                      131     0.282443   37
# 5191-5690                       14     0.285714    4
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\2440674755.py:12: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   grouped_data = df_SNP_Adjusted.pivot_table(

# %%
# יצירת טבלת טווחים DXY
min_val = int(df['DXY Adjusted'].min())
max_val = int(df['DXY Adjusted'].max())
ranges = list(range(min_val, max_val + 10, 10)) 
df['ranges_DXY_Adjusted'] = pd.cut(df['DXY Adjusted'], bins=ranges, labels=[f"{r}-{r+1}" for r in ranges[:-1]])

print(df['ranges_DXY_Adjusted'])

import copy
df_DXY_Adjusted = copy.deepcopy(df)

# חישוב סטטיסטיקות עבור כל טווח
grouped_data = df_DXY_Adjusted.pivot_table( 
    index='ranges_DXY_Adjusted',
    values=['DXY Adjusted', 'Target Value'], 
    
    aggfunc={'DXY Adjusted': 'count', 'Target Value': ['sum', 'mean']}, )

# הצגת הטבלה
print(grouped_data)
# Out:
# 0       98-99
# 1       98-99
# 2       98-99
# 3       98-99
# 4       98-99
#         ...
# 2643    98-99
# 2644    98-99
# 2645    98-99
# 2646    98-99
# 2647    98-99
# Name: ranges_DXY_Adjusted, Length: 2648, dtype: category
# Categories (3, object): ['88-89' < '98-99' < '108-109']
#                     DXY Adjusted Target Value
#                            count         mean  sum
# ranges_DXY_Adjusted
# 88-89                       1675     0.346269  580
# 98-99                        888     0.228604  203
# 108-109                       85     0.176471   15
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\3453390139.py:13: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   grouped_data = df_DXY_Adjusted.pivot_table(

# %%
# יצירת עמודת טווחים DXY Adjusted
# min_val = int(df['DXY Adjusted'].min())
min_val = int(88)
max_val = int(89)
ranges = list(range(min_val, max_val + 3, 3))
df['ranges_DXY Adjusted'] = pd.cut(df['DXY Adjusted'], bins=ranges, labels=[f"{r}-{r+1}" for r in ranges[:-1]])
# print(df.ranges_GOLD_Adjusted)

import copy
df1 = copy.deepcopy(df)

min_val = int(98)
max_val = int(109)
ranges = list(range(min_val, max_val + 13, 13))
df1['ranges_DXY Adjusted'] = pd.cut(df1['DXY Adjusted'], bins=ranges, labels=[f"{r}-{r+11}" for r in ranges[:-1]])
# print(df1.ranges_GOLD_Adjusted)

# טבלה חדשה לזהב המחשבת אחוזים
# טען את נתוני 'df'
# dfGold = df.copy.deepcopy()
import copy
dfGold = copy.deepcopy(df)


# ודא ש-SN&P Adjusted הוא מסוג int
dfGold['DXY Adjusted'] = dfGold['DXY Adjusted'].astype(int)
# צור טבלה חדשה עם טווחים, ספירה, סכום TARGET_VALUE וחישוב אחוז
grouped_data = (
    dfGold.pivot_table(
        index='ranges_DXY Adjusted',
        values=['DXY Adjusted', 'Target Value'],
        aggfunc={'DXY Adjusted': 'count', 'Target Value': ['sum', 'mean']},
    ).reset_index()
)
print(grouped_data)

import copy
dfGold1 = copy.deepcopy(df1)

# ודא ש-DXY Adjusted הוא מסוג int
dfGold1['DXY Adjusted'] = dfGold1['DXY Adjusted'].astype(int)
# צור טבלה חדשה עם טווחים, ספירה, סכום TARGET_VALUE וחישוב אחוז
grouped_data = (
    dfGold1.pivot_table(
        index='ranges_DXY Adjusted',
        values=['DXY Adjusted', 'Target Value'],
        aggfunc={'DXY Adjusted': 'count', 'Target Value': ['sum', 'mean']},
    ).reset_index()
)
print(grouped_data)
# Out:
#   ranges_DXY Adjusted DXY Adjusted Target Value
#                              count         mean  sum
# 0               88-89          250        0.492  123
#   ranges_DXY Adjusted DXY Adjusted Target Value
#                              count         mean  sum
# 0              98-109          935     0.225668  211
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\1653062902.py:29: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dfGold.pivot_table(
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\1653062902.py:44: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dfGold1.pivot_table(

# %%
# יצירת טבלת טווחים ETH Price
min_val = int(df['ETH Price'].min())
max_val = int(df['ETH Price'].max())
ranges = list(range(min_val, max_val + 10, 10)) 
df['ranges_ETH_Price'] = pd.cut(df['ETH Price'], bins=ranges, labels=[f"{r}-{r+1}" for r in ranges[:-1]])

print(df['ranges_ETH_Price'])

# df_ETH_Price = df.copy()
import copy
df_ETH_Price = copy.deepcopy(df)


# חישוב סטטיסטיקות עבור כל טווח
grouped_data = df_ETH_Price.pivot_table( 
    index='ranges_ETH_Price',
    values=['ETH Price', 'Target Value'], 
    
    aggfunc={'ETH Price': 'count', 'Target Value': ['sum', 'mean']}, )

# הצגת הטבלה
print(grouped_data)
# Out:
# 0       3160-3161
# 1       3150-3151
# 2       3050-3051
# 3       3060-3061
# 4       2980-2981
#           ...
# 2643        10-11
# 2644        10-11
# 2645        10-11
# 2646        10-11
# 2647        10-11
# Name: ranges_ETH_Price, Length: 2648, dtype: category
# Categories (480, object): ['10-11' < '20-21' < '30-31' < '40-41' ... '4770-4771' < '4780-4781' < '4790-4791' < '4800-4801']
#                  ETH Price Target Value
#                      count         mean sum
# ranges_ETH_Price
# 10-11                   49     0.204082  10
# 20-21                    4     0.500000   2
# 30-31                    2     0.500000   1
# 40-41                   25     0.360000   9
# 50-51                   16     0.125000   2
# ...                    ...          ...  ..
# 4760-4761                0          NaN   0
# 4770-4771                0          NaN   0
# 4780-4781                0          NaN   0
# 4790-4791                0          NaN   0
# 4800-4801                1     1.000000   1
#
# [480 rows x 3 columns]
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\2223384988.py:15: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   grouped_data = df_ETH_Price.pivot_table(

# %%
# יצירת עמודת טווחים ETH Price
# min_val = int(df['DXY Adjusted'].min())
min_val = int(10)
max_val = int(2401)
ranges = list(range(min_val, max_val + 2393, 2393))
df['ranges_ETH Price'] = pd.cut(df['ETH Price'], bins=ranges, labels=[f"{r}-{r+2391}" for r in ranges[:-1]])
# print(df.ranges_GOLD_Adjusted)

import copy
df1 = copy.deepcopy(df)

min_val = int(2401)
max_val = int(4801)
ranges = list(range(min_val, max_val + 2401, 2401))
df1['ranges_ETH Price'] = pd.cut(df1['ETH Price'], bins=ranges, labels=[f"{r}-{r+2399}" for r in ranges[:-1]])
# print(df1.ranges_GOLD_Adjusted)

# טבלה חדשה לזהב המחשבת אחוזים
# טען את נתוני 'df'
# dfGold = df.copy.deepcopy()
import copy
dfGold = copy.deepcopy(df)


# ודא ש-SN&P Adjusted הוא מסוג int
dfGold['ETH Price'] = dfGold['ETH Price'].astype(int)
# צור טבלה חדשה עם טווחים, ספירה, סכום TARGET_VALUE וחישוב אחוז
grouped_data = (
    dfGold.pivot_table(
        index='ranges_ETH Price',
        values=['ETH Price', 'Target Value'],
        aggfunc={'ETH Price': 'count', 'Target Value': ['sum', 'mean']},
    ).reset_index()
)
print(grouped_data)

import copy
dfGold1 = copy.deepcopy(df1)

# ודא ש-DXY Adjusted הוא מסוג int
dfGold1['ETH Price'] = dfGold1['ETH Price'].astype(int)
# צור טבלה חדשה עם טווחים, ספירה, סכום TARGET_VALUE וחישוב אחוז
grouped_data = (
    dfGold1.pivot_table(
        index='ranges_ETH Price',
        values=['ETH Price', 'Target Value'],
        aggfunc={'ETH Price': 'count', 'Target Value': ['sum', 'mean']},
    ).reset_index()
)
print(grouped_data)
# Out:
#   ranges_ETH Price ETH Price Target Value
#                        count         mean  sum
# 0          10-2401      2230     0.297758  664
#   ranges_ETH Price ETH Price Target Value
#                        count         mean  sum
# 0        2401-4800       418     0.320574  134
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\3061232438.py:29: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dfGold.pivot_table(
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_15976\3061232438.py:44: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dfGold1.pivot_table(

# %%
# יצירת טבלת טווחים Vol.
min_val = int(df['Vol.'].min())
max_val = int(df['Vol.'].max())

ranges = list(range(min_val, max_val + 10000, 10000)) 
df['ranges_Vol'] = pd.cut(df['Vol'], bins=ranges, labels=[f"{r}-{r+4999}" for r in ranges[:-1]])

print(df['ranges_Vol'])


df_Vol = df.copy()

# חישוב סטטיסטיקות עבור כל טווח
grouped_data = df_Vol.pivot_table( 
    index='ranges_Vol',
    values=['Vol', 'Target Value'], 
    
    aggfunc={'Vol': 'count', 'Target Value': ['sum', 'mean']}, )

# הצגת הטבלה
print(grouped_data)

# יצירת טבלת טווחים Vol.
# Min and max values for  
min_val = df['Vol.'].min()
max_val = df['Vol.'].max()

# # Create ranges using np.arange for floats
ranges = np.arange(min_val, max_val + 1, 1)

# # Cut with the created ranges (labels are optional here)
df['ranges_Vol.'] = pd.cut(df['Vol.'], bins=ranges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # יצירת טבלת טווחים Vol.
# ----> 2 min_val = int(df['Vol.'].min())
#       3 max_val = int(df['Vol.'].max())
#       5 ranges = list(range(min_val, max_val + 10000, 10000))
#
# ValueError: invalid literal for int() with base 10: '0.26K'

# %%
# יצירת טבלת טווחים OIL Price Adjusted
min_val = int(df['OIL Price Adjusted'].min())
max_val = int(df['OIL Price Adjusted'].max())
ranges = list(range(min_val, max_val + 9, 9)) 
df['ranges_OIL Price Adjusted'] = pd.cut(df['OIL Price Adjusted'], bins=ranges, labels=[f"{r}-{r+1}" for r in ranges[:-1]])

print(df['ranges_OIL Price Adjusted'])

# df_ETH_Price = df.copy()
import copy
df_ETH_Price = copy.deepcopy(df)


# חישוב סטטיסטיקות עבור כל טווח
grouped_data = df_ETH_Price.pivot_table( 
    index='ranges_OIL Price Adjusted',
    values=['OIL Price Adjusted', 'Target Value'], 
    
    aggfunc={'OIL Price Adjusted': 'count', 'Target Value': ['sum', 'mean']}, )

# הצגת הטבלה
print(grouped_data)
# Out:
# 0       82-83
# 1       82-83
# 2       82-83
# 3       82-83
# 4       82-83
#         ...
# 2643    46-47
# 2644    46-47
# 2645    46-47
# 2646    46-47
# 2647    46-47
# Name: ranges_OIL Price Adjusted, Length: 2648, dtype: category
# Categories (13, object): ['10-11' < '19-20' < '28-29' < '37-38' ... '91-92' < '100-101' < '109-110' < '118-119']
#                           OIL Price Adjusted Target Value
#                                        count         mean  sum
# ranges_OIL Price Adjusted
# 10-11                                     14     0.285714    4
# 19-20                                     42     0.404762   17
# 28-29                                     40     0.350000   14
# 37-38                                    231     0.238095   55
# 46-47                                    487     0.373717  182
# 55-56                                    503     0.367793  185
# 64-65                                    487     0.308008  150
# 73-74                                    421     0.206651   87
# 82-83                                    221     0.199095   44
# 91-92                                     81     0.271605   22
# 100-101                                   60     0.316667   19
# 109-110                                   47     0.319149   15
# 118-119                                   14     0.285714    4
# C:\Users\אריה ושרי אטינגר\AppData\Local\Temp\ipykernel_25264\2504811640.py:15: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   grouped_data = df_ETH_Price.pivot_table(
